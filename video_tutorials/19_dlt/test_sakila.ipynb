# %% [markdown]
# # Check sakila

# %%
import duckdb

with duckdb.connect("data/sakila.duckdb") as conn:
    description = conn.sql("DESC;").df()

description
# Out:
#    database   schema                 name  \
# 0    sakila  staging           _dlt_loads
# 1    sakila  staging  _dlt_pipeline_state
# 2    sakila  staging         _dlt_version
# 3    sakila  staging                actor
# 4    sakila  staging              address
# 5    sakila  staging             category
# 6    sakila  staging                 city
# 7    sakila  staging              country
# 8    sakila  staging             customer
# 9    sakila  staging                 film
# 10   sakila  staging           film_actor
# 11   sakila  staging        film_category
# 12   sakila  staging            inventory
# 13   sakila  staging             language
# 14   sakila  staging              payment
# 15   sakila  staging               rental
# 16   sakila  staging                staff
# 17   sakila  staging                store
#
#                                          column_names  \
# 0   [load_id, schema_name, status, inserted_at, sc...
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [actor_id, first_name, last_name, last_update,...
# 4   [address_id, address, address2, district, city...
# 5   [category_id, name, last_update, _dlt_load_id,...
# 6   [city_id, city, country_id, last_update, _dlt_...
# 7   [country_id, country, last_update, _dlt_load_i...
# 8   [customer_id, store_id, first_name, last_name,...
# 9   [film_id, title, description, release_year, la...
# 10  [actor_id, film_id, last_update, _dlt_load_id,...
# 11  [film_id, category_id, last_update, _dlt_load_...
# 12  [inventory_id, film_id, store_id, last_update,...
# 13  [language_id, name, last_update, _dlt_load_id,...
# 14  [payment_id, customer_id, staff_id, rental_id,...
# 15  [rental_id, rental_date, inventory_id, custome...
# 16  [staff_id, first_name, last_name, address_id, ...
# 17  [store_id, manager_staff_id, address_id, last_...
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [DECIMAL(38,9), VARCHAR, VARCHAR, TIMESTAMP, V...      False
# 4   [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, VA...      False
# 5      [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]      False
# 6   [BIGINT, VARCHAR, BIGINT, TIMESTAMP, VARCHAR, ...      False
# 7      [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]      False
# 8   [BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, BI...      False
# 9   [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, BI...      False
# 10      [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]      False
# 11      [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]      False
# 12  [BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, V...      False
# 13     [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]      False
# 14  [BIGINT, BIGINT, BIGINT, BIGINT, DECIMAL(5,2),...      False
# 15  [BIGINT, TIMESTAMP, BIGINT, BIGINT, TIMESTAMP,...      False
# 16  [BIGINT, VARCHAR, VARCHAR, BIGINT, BLOB, VARCH...      False
# 17  [BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, V...      False

# %% [markdown]
# ## Storing data into dictionary of dfs

# %%
dfs = {}

with duckdb.connect("data/sakila.duckdb") as conn:
    for name in description["name"]:
        if name[0] != '_':
            dfs[name] = conn.sql(f"FROM staging.{name};").df()

            duckdb.register(name, dfs[name])

dfs["film"].head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...         2006
# 1  A Astounding Epistle of a Database Administrat...         2006
# 2  A Astounding Reflection of a Lumberjack And a ...         2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...         2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...         2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                  <NA>                6         0.99      86
# 1            1                  <NA>                3         4.99      48
# 2            1                  <NA>                7         2.99      50
# 3            1                  <NA>                5         2.99     117
# 4            1                  <NA>                6         2.99     130
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
# 1             12.99      G           Trailers,Deleted Scenes
# 2             18.99  NC-17           Trailers,Deleted Scenes
# 3             26.99      G    Commentaries,Behind the Scenes
# 4             22.99      G                    Deleted Scenes
#
#           last_update        _dlt_load_id         _dlt_id
# 0 2021-03-06 15:52:00  1765183073.4357996  ArINAm00tJCvMQ
# 1 2021-03-06 15:52:00  1765183073.4357996  Hi37xXDCnQEIqg
# 2 2021-03-06 15:52:00  1765183073.4357996  TW/IMlfXBjT5WA
# 3 2021-03-06 15:52:00  1765183073.4357996  D0xUmDwGYXg35w
# 4 2021-03-06 15:52:00  1765183073.4357996  K3iCuVvzyOuXmQ

# %%
duckdb.sql("DESC;")
# Out:
# ┌──────────┬─────────┬───────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┐
# │ database │ schema  │     name      │                                                                                             column_names                                                                                             │                                                            column_types                                                            │ temporary │
# │ varchar  │ varchar │    varchar    │                                                                                              varchar[]                                                                                               │                                                             varchar[]                                                              │  boolean  │
# ├──────────┼─────────┼───────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┤
# │ temp     │ main    │ actor         │ [actor_id, first_name, last_name, last_update, _dlt_load_id, _dlt_id]                                                                                                                                │ [DOUBLE, VARCHAR, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]                                                                            │ true      │
# │ temp     │ main    │ address       │ [address_id, address, address2, district, city_id, postal_code, phone, last_update, _dlt_load_id, _dlt_id]                                                                                           │ [BIGINT, VARCHAR, '"NULL"', VARCHAR, BIGINT, VARCHAR, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]                                        │ true      │
# │ temp     │ main    │ category      │ [category_id, name, last_update, _dlt_load_id, _dlt_id]                                                                                                                                              │ [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]                                                                                     │ true      │
# │ temp     │ main    │ city          │ [city_id, city, country_id, last_update, _dlt_load_id, _dlt_id]                                                                                                                                      │ [BIGINT, VARCHAR, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]                                                                             │ true      │
# │ temp     │ main    │ country       │ [country_id, country, last_update, _dlt_load_id, _dlt_id]                                                                                                                                            │ [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]                                                                                     │ true      │
# │ temp     │ main    │ customer      │ [customer_id, store_id, first_name, last_name, email, address_id, active, create_date, last_update, _dlt_load_id, _dlt_id]                                                                           │ [BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, VARCHAR, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR]                               │ true      │
# │ temp     │ main    │ film          │ [film_id, title, description, release_year, language_id, original_language_id, rental_duration, rental_rate, length, replacement_cost, rating, special_features, last_update, _dlt_load_id, _dlt_id] │ [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, BIGINT, DOUBLE, VARCHAR, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR] │ true      │
# │ temp     │ main    │ film_actor    │ [actor_id, film_id, last_update, _dlt_load_id, _dlt_id]                                                                                                                                              │ [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]                                                                                      │ true      │
# │ temp     │ main    │ film_category │ [film_id, category_id, last_update, _dlt_load_id, _dlt_id]                                                                                                                                           │ [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]                                                                                      │ true      │
# │ temp     │ main    │ inventory     │ [inventory_id, film_id, store_id, last_update, _dlt_load_id, _dlt_id]                                                                                                                                │ [BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]                                                                              │ true      │
# │ temp     │ main    │ language      │ [language_id, name, last_update, _dlt_load_id, _dlt_id]                                                                                                                                              │ [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]                                                                                     │ true      │
# │ temp     │ main    │ payment       │ [payment_id, customer_id, staff_id, rental_id, amount, payment_date, last_update, _dlt_load_id, _dlt_id]                                                                                             │ [BIGINT, BIGINT, BIGINT, BIGINT, DOUBLE, TIMESTAMP, TIMESTAMP, VARCHAR, VARCHAR]                                                   │ true      │
# │ temp     │ main    │ rental        │ [rental_id, rental_date, inventory_id, customer_id, return_date, staff_id, last_update, _dlt_load_id, _dlt_id]                                                                                       │ [BIGINT, TIMESTAMP, BIGINT, BIGINT, TIMESTAMP, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]                                                │ true      │
# │ temp     │ main    │ staff         │ [staff_id, first_name, last_name, address_id, picture, email, store_id, active, username, password, last_update, _dlt_load_id, _dlt_id]                                                              │ [BIGINT, VARCHAR, VARCHAR, BIGINT, '"NULL"', VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]               │ true      │
# │ temp     │ main    │ store         │ [store_id, manager_staff_id, address_id, last_update, _dlt_load_id, _dlt_id]                                                                                                                         │ [BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]                                                                              │ true      │
# ├──────────┴─────────┴───────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┤
# │ 15 rows                                                                                                                                                                                                                                                                                                                                                                          6 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duckdb.sql("SELECT first_name, last_name FROM actor;").df()
# Out:
#     first_name     last_name
# 0     PENELOPE       GUINESS
# 1         NICK      WAHLBERG
# 2           ED         CHASE
# 3     JENNIFER         DAVIS
# 4       JOHNNY  LOLLOBRIGIDA
# ..         ...           ...
# 195       BELA        WALKEN
# 196      REESE          WEST
# 197       MARY        KEITEL
# 198      JULIA       FAWCETT
# 199      THORA        TEMPLE
#
# [200 rows x 2 columns]

# %%
# Out:
# UsageError: Cell magic `%%duckdb` not found.
